# %%
#Code that I am working to improve

import requests
import json
import pandas as pd


response_list = []

# Create the first connection to get started
endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
response = requests.get(endpoint, headers=headers).json()
response_dict = dict(response)
# Determine if hasMore is equal to True
has_more = response_dict.get('pageInfo', {}).get('hasMore')
# Use the .get method on the dictionary to pull out the cursor value
cursor_value = str(response_dict.get('pageInfo', {}).get('cursor'))
response_list.append(cursor_value)

#loop through the rest of the pages to get the cursor values
for x in range(1, 15):
    next_endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
    next_response_url = next_endpoint +"?cursor="+ cursor_value
    next_response = requests.get(next_response_url, headers=headers).json()
    next_response_dict = dict(next_response)
    has_more = next_response_dict.get('pageInfo', {}).get('hasMore')
    cursor_value = str(next_response_dict.get('pageInfo', {}).get('cursor'))
    response_list.append(cursor_value)
    
    
    
loops = 0

# use the cursor values in the response list now to get the data. Convert to a JSON then to a dictionary and then to a dataframe.
for cursor in response_list:
    loops +=1
    endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"+"?cursor="+cursor
    headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
    response = requests.get(endpoint, headers=headers).json()
    response_dict = dict(response)
    event_dict = { key:value for (key,value) in response_dict.items() if key == "events"}
    events_unnested = event_dict.get('events', {}) 
    if loops == 1:
        course_data_df = pd.DataFrame.from_dict(events_unnested)
    else:
        to_append = pd.DataFrame.from_dict(events_unnested)
        course_data_df = course_data_df.append(to_append)
        
del to_append
        
course_data_df
# Out:
#                                       id license            source  \
# 0   3de0cff0-88f1-49db-96ab-ebc46066651e    None  course_completed
# 1   c9f48c64-be66-4de8-96c0-b60510e5ebcf    None  course_completed
# 2   85c4cb6c-94d9-4f48-9dd1-00cfd0128fe1    None  course_completed
# 3   49a16e29-0e22-4732-970d-feb90cc868d3    None  course_completed
# 4   49c7863d-1460-4ce5-8c3f-75a94330c8cf    None  course_completed
# ..                                   ...     ...               ...
# 95  6c741fa6-0f43-4c64-ae76-dcf8567bc6ad    None  course_completed
# 96  0aa18161-eabd-43dc-be75-c921db543ebe    None  course_completed
# 97  6abb58b2-b8bb-40fc-9801-ab8bacdc9da4    None  course_completed
# 98  f0b17aa8-b6d2-4075-9870-f8a9dd20872a    None  course_completed
# 99  b96da0d9-1f4e-4592-8e7d-ba6ad51034f6    None  course_completed
#
#                    timestamp           type                 updatedAt  \
# 0   2021-02-24T20:54:15.748Z  status_change  2021-02-24T20:54:15.746Z
# 1   2021-02-24T20:52:20.398Z  status_change  2021-02-24T20:52:20.400Z
# 2   2021-02-24T20:50:38.528Z  status_change  2021-02-24T20:50:38.528Z
# 3   2021-02-24T20:48:27.112Z  status_change  2021-02-24T20:48:27.115Z
# 4   2021-02-24T20:47:12.409Z  status_change  2021-02-24T20:47:12.407Z
# ..                       ...            ...                       ...
# 95  2021-02-10T18:29:01.309Z  status_change  2021-02-10T18:29:01.312Z
# 96  2021-02-10T18:22:12.005Z  status_change  2021-02-10T18:22:12.017Z
# 97  2021-02-10T18:20:05.975Z  status_change  2021-02-10T18:20:05.984Z
# 98  2021-02-10T18:18:38.636Z  status_change  2021-02-10T18:18:38.641Z
# 99  2021-02-10T18:18:03.946Z  status_change  2021-02-10T18:18:03.948Z
#
#                              user                             companyId  \
# 0     nikolay.eraskin@ermolov.pro  e546d2da-8954-4b2d-adbe-0138517b4dba
# 1          adam.royall@ivanti.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 2           laker.cook@ivanti.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 3         rodney.manor@ivanti.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 4         rodney.manor@ivanti.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# ..                            ...                                   ...
# 95       simonhulse@moorgroup.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 96          david.ajas@ivanti.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 97       simonhulse@moorgroup.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 98  jklindsey@firstunitedbank.com  e546d2da-8954-4b2d-adbe-0138517b4dba
# 99       simonhulse@moorgroup.com  e546d2da-8954-4b2d-adbe-0138517b4dba
#
#                event                          notifiableId  \
# 0   courseCompletion  2db5ab71-5510-4487-8d3e-6ae2907c2258
# 1   courseCompletion  09590e91-39ad-44bd-a94c-e938a4aaae90
# 2   courseCompletion  a41419d2-8c38-4460-9ead-670c20458c4d
# 3   courseCompletion  b0616eb4-92e5-47b9-88fd-e25f3366de03
# 4   courseCompletion  b0616eb4-92e5-47b9-88fd-e25f3366de03
# ..               ...                                   ...
# 95  courseCompletion  83e5d172-c4c1-450c-97a2-356487b6be7e
# 96  courseCompletion  4664c9be-9f45-498a-a610-59651db8ae43
# 97  courseCompletion  9a3967a9-d10f-40ea-99da-173182b73092
# 98  courseCompletion  43a40154-bd30-4ba0-9241-570abb79c448
# 99  courseCompletion  4aa88e36-d897-4dc5-a05c-b6166f4e9c15
#
#                                                 title  \
# 0   Service Manager - Setting up External Authenti...
# 1   Endpoint Manager - Provisioning Capture and De...
# 2                   Endpoint Manager - Device Control
# 3         Endpoint Manager - Core Server Architecture
# 4         Endpoint Manager - Core Server Architecture
# ..                                                ...
# 95     Asset Manager - Administrator: Getting Started
# 96  Endpoint Manager - Role Based Administration I...
# 97   Service Manager - Creating Roles and Permissions
# 98  Endpoint Manager - Software Distribution Archi...
# 99                      Ivanti Asset Manager Overview
#
#                                            userDetail
# 0   {'id': '5c7dd3cd-602b-4131-9e91-a1d54c264422',...
# 1   {'id': '70f17bff-1ac6-4d94-997a-8eab8654e3bd',...
# 2   {'id': 'b0c550df-dd6c-42f8-8991-9baeef13190b',...
# 3   {'id': '7e60edf2-d360-4c29-8bb1-d8751e1af771',...
# 4   {'id': '7e60edf2-d360-4c29-8bb1-d8751e1af771',...
# ..                                                ...
# 95  {'id': '08c1609e-84fd-446d-8650-44c29c7d74d8',...
# 96  {'id': '48ffc585-a89c-4662-a567-a3daf3abdde4',...
# 97  {'id': '08c1609e-84fd-446d-8650-44c29c7d74d8',...
# 98  {'id': 'cd03aa60-e07d-4878-a540-5e374adc0003',...
# 99  {'id': '08c1609e-84fd-446d-8650-44c29c7d74d8',...
#
# [1500 rows x 12 columns]

# %%
#Combined Script # Working Code


#import requests
#import json
#from datetime import time
#from datetime import datetime
#from datetime import timedelta
#import pandas as pd


#now = datetime.now()
#now_unix = now.timestamp()
#one_week_unix = 604800
#one_week_ago_unix = str(now_unix - one_week_unix)

#response_list = []

# Create the first connection to get started
#endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"+"?startDate="+one_week_ago_unix
#headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
#response = requests.get(endpoint, headers=headers).json()
#response_dict = dict(response)
# Determine if hasMore is equal to True
#has_more = response_dict.get('pageInfo', {}).get('hasMore')
# Use the .get method on the dictionary to pull out the cursor value
#cursor_value = str(response_dict.get('pageInfo', {}).get('cursor'))
#response_list.append(cursor_value)

#loop through all of the pages
#for x in range(1, 50):
#    next_endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
 #   next_response_url = next_endpoint +"?cursor="+ cursor_value
#    next_response = requests.get(next_response_url, headers=headers).json()
#    next_response_dict = dict(next_response)
#    has_more = next_response_dict.get('pageInfo', {}).get('hasMore')
#    if has_more == "false":
#        break
#    cursor_value = next_response_dict.get('pageInfo', {}).get('cursor')
#    response_list.append(cursor_value)
    
#loops = 0

# use the cursor values in the response list now to get the data. Convert to a JSON then to a dictionary and then to a dataframe.
#for cursor in response_list:
#    loops +=1
#    endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"+"?cursor="+cursor
#    headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
#    response = requests.get(endpoint, headers=headers).json()
#    response_dict = dict(response)
#    event_dict = { key:value for (key,value) in response_dict.items() if key == "events"}
 #   events_unnested = event_dict.get('events', {}) 
 #   if loops == 1:
 #       course_data_df = pd.DataFrame.from_dict(events_unnested)
 #   else:
#        to_append = pd.DataFrame.from_dict(events_unnested)
 #       course_data_df = course_data_df.append(to_append)

# %%
#Code that I am working to improve

import requests
import json
import pandas as pd


response_list = []

# Create the first connection to get started
endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
response = requests.get(endpoint, headers=headers).json()
response_dict = dict(response)
# Determine if hasMore is equal to True
has_more = response_dict.get('pageInfo', {}).get('hasMore')
# Use the .get method on the dictionary to pull out the cursor value
cursor_value = str(response_dict.get('pageInfo', {}).get('cursor'))
response_list.append(cursor_value)

type(cursor_value)
# Out:
# str

# %%
#course_data_df
    
    #with open("to_load.json", "w") as file:
        #json.dump(data_to_load, file)

# %%
#Code that works for pulling numbers
#import requests
#import json

#endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
#headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
#response = requests.get(endpoint, headers=headers).json()
#response_dict = dict(response)
# Determine if hasMore is equal to True
#has_more = response_dict.get('pageInfo', {}).get('hasMore')
# Use the .get method on the dictionary to pull out the cursor value
#cursor_value = response_dict.get('pageInfo', {}).get('cursor') 
#response_list.append(cursor_value)

#for x in range(1, 50):
#    next_url = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
#    next_response_url = next_url+"?cursor="+cursor_value
#    next_response = requests.get(next_response_url, headers=headers).json()
#    next_response_dict = dict(next_response)
#    cursor_value = next_response_dict.get('pageInfo', {}).get('cursor')
#    response_list.append(cursor_value)

   
#print(response_list)

# %%
# This was my original code
#import requests
#import json

#response_list = []

#endpoint = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"
#headers = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
#response = requests.get(endpoint, headers=headers)
#r_json = response.json()
#r_dict = dict(r_json)
# Determine if hasMore is equal to True
#has_more = r_dict.get('pageInfo', {}).get('hasMore')
# Use the .get method on the dictionary to pull out the cursor value
#cursor_value = r_dict.get('pageInfo', {}).get('cursor') 
#response_list.append(cursor_value)

# %%
#with open('data.json', 'w') as f:
  #  json.dump(all_dict, f)

# %%
#endpoint2 = "https://advantagelearning.ivanti.com/incoming/v2/events/courseCompletion"+ "?cursor="+ cursor_value
#headers2 = {"Authorization": "Bearer gt5wpufdsoylx1tldapvmnk99gle7pz4"}
#s = requests.get(endpoint2, headers=headers2)
#print(s.json())
